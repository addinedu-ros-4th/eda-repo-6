# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
from bs4 import BeautifulSoup
import json
import pandas as pd
import time
client_id = "vz346cK6Vu4YSBtqMf7Y"
client_secret = "xWgqw9t0T4"
def search(text,start):
    
    encText = urllib.parse.quote(text)
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText+"&display=100"+"&start="+str(start) # JSON 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        return pd.DataFrame(json.loads(response.read()))
        
    else:
        return ("Error Code:" + rescode)
titles = []
links = []
descs = []
bloggernames = []
bloggerlinks = []
postdates = []
dates = []
news2018_list = []
text = "2022년 부동산 결산"    
for i in range(1,100):
    res = search(text,i)
    time.sleep(0.3)
    

    new_data = res["items"]
    for i,content in new_data.items():
        titles.append(content["title"])
        links.append(content["link"])
        descs.append(content["description"])
        postdates.append(content["postdate"])
        bloggernames.append(content["bloggername"])
        bloggerlinks.append(content["bloggerlink"])

# %%
from bs4 import BeautifulSoup
def remove_html_tags_bs(text):
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text()

for i in descs:
    
    text_without_tags = remove_html_tags_bs(i)
    print(text_without_tags)
# Out:
# 2023년 6월 중순 2022년 매수하였던 빌라에 살고 있던 임차인(전 주인의 아들딸)이 드디어 이사하여 도배와 소소한 수리를 진행하였다. 다시 월세 세팅을 하려고 부동산에 내놨는데 한 부동산에서 제발 좀...
# 벌써 2023년이 지나고 2024년 새해가 시작했네요 모두 2023년 한해 고생많으셨고 24년 새해복 많이... 3개정도의 부동산 투자를 하였고 에어비앤비 오피스텔로 한건 진행중이였죠 그럼 하나하나 복기를 하면서...
# 오늘은 서울특별시 도봉구 창동에서 부동산을 업으로 삼고 있는 한 사람으로서 2023년도 부동산 흐름에 대하여 끄적여 보도록 하겠습니다 23년도는 22년하반기에 부동산 침체상황 그대로 바턴을 이어받아...
# 새해가 되어서야 실행하는 연간 리뷰 및 목표 설정 시리즈, 주식 및 부동산 투자 편입니다. 1. 미국 주식 투자 1) 수익률: +21% 2023년 AI 열풍 덕분에 포트폴리오의 대부분을 차지하는 대형 기술주(애플...
# 2023년 정부 부동산 정책 결산 2023년 부동산 정책 결산을 해보겠습니다. 굵직 굵직한 정책들이 있었습니다. √ 우선 대출 관련 정책인데요. 일반형 특례보금자리론은 막강한 영향력을 보였습니다. 초반...
# 유료방 아닙니다 ㅎㅎ 2023년 부동산 시장에 대해 간략하게 결산을 해볼까 합니다. 시장을 예측하는 것이 중요하지만 지나간 시장을 복기하면서 분석하는 것 역시 매우 중요합니다. 수도권은 22년에 이어...
# □ 2023년 서울 부동산 결산 (KB부동산 아파트 기준) - 매매 지수 상승률 : -6.19% - 전세 지수 상승률 : -8.79% 2022년은 그렇다치고 2023년도 하락한 것으로 나오는 KB부동산 데이터에 위화감을 느끼는 분들이...
# 부동산은 지역별로 편차가 크기 때문에 금융 자산과 대체 자산 중심으로 2023년을 결산해 보고 2024년을 어떻게 준비하는 것이 현명할 것인지 살펴보겠습니다. (단,모든 경제지표는 NAVER 자료를...
# ...

# %%
from bs4 import BeautifulSoup
def remove_html_tags_bs(text):
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text()

for i in descs:
    
    text_without_tags = remove_html_tags_bs(i)
    if "아파트" in i and "2022" in i:
        print(text_without_tags)
